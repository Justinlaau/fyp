# %%
import pandas as pd
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.vector_ar.vecm import coint_johansen
# Import Statsmodels
from statsmodels.tsa.api import VAR, VARMAX
from statsmodels.tsa.stattools import adfuller
from statsmodels.tools.eval_measures import rmse, aic

from statsmodels.tsa.stattools import grangercausalitytests
from statsmodels.stats.stattools import durbin_watson

# %%
def cointegration_test(df, alpha=0.05): 
    """Perform Johanson's Cointegration Test and Report Summary"""
    out = coint_johansen(df,-1,5)
    d = {'0.90':0, '0.95':1, '0.99':2}
    traces = out.lr1
    cvts = out.cvt[:, d[str(1-alpha)]]
    def adjust(val, length= 6): return str(val).ljust(length)

    # Summary
    print('Name   ::  Test Stat > C(95%)    =>   Signif  \n', '--'*20)
    for col, trace, cvt in zip(df.columns, traces, cvts):
        print(adjust(col), ':: ', adjust(round(trace,2), 9), ">", adjust(cvt, 8), ' =>  ' , trace > cvt)

# %%
maxlag=12
test = 'ssr_chi2test'
def grangers_causation_matrix(data, variables, test='ssr_chi2test', verbose=False):    
    """Check Granger Causality of all possible combinations of the Time series.
    The rows are the response variable, columns are predictors. The values in the table 
    are the P-Values. P-Values lesser than the significance level (0.05), implies 
    the Null Hypothesis that the coefficients of the corresponding past values is 
    zero, that is, the X does not cause Y can be rejected.

    data      : pandas dataframe containing the time series variables
    variables : list containing names of the time series variables.
    """
    df = pd.DataFrame(np.zeros((len(variables), len(variables))), columns=variables, index=variables)
    for c in df.columns:
        for r in df.index:
            test_result = grangercausalitytests(data[[r, c]], maxlag=maxlag)
            p_values = [round(test_result[i+1][0][test][1],4) for i in range(maxlag)]
            if verbose: print(f'Y = {r}, X = {c}, P Values = {p_values}')
            min_p_value = np.min(p_values)
            df.loc[r, c] = min_p_value
    df.columns = [var + '_x' for var in variables]
    df.index = [var + '_y' for var in variables]
    return df

# %%
def adfuller_test(series, signif=0.05, name='', verbose=False):
    """Perform ADFuller to test for Stationarity of given series and print report"""
    r = adfuller(series, autolag='AIC')
    output = {'test_statistic':round(r[0], 4), 'pvalue':round(r[1], 4), 'n_lags':round(r[2], 4), 'n_obs':r[3]}
    p_value = output['pvalue'] 
    def adjust(val, length= 6): return str(val).ljust(length)

    # Print Summary
    print(f'    Augmented Dickey-Fuller Test on "{name}"', "\n   ", '-'*47)
    print(f' Null Hypothesis: Data has unit root. Non-Stationary.')
    print(f' Significance Level    = {signif}')
    print(f' Test Statistic        = {output["test_statistic"]}')
    print(f' No. Lags Chosen       = {output["n_lags"]}')

    for key,val in r[4].items():
        print(f' Critical value {adjust(key)} = {round(val, 3)}')

    if p_value <= signif:
        print(f" => P-Value = {p_value}. Rejecting Null Hypothesis.")
        print(f" => Series is Stationary.")
    else:
        print(f" => P-Value = {p_value}. Weak evidence to reject the Null Hypothesis.")
        print(f" => Series is Non-Stationary.")

# %% [markdown]
# # Import data

# %%
df = pd.read_csv("quaterly_data.csv", parse_dates=['date'], index_col='date')
df = df.fillna(df.mean()).dropna()

# %% [markdown]
# # Testing Causation using Granger’s Causality Test

# %%
grangers_causation_matrix(df, variables = df.columns)
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=-0.0000 , p=1.0000  , df_denom=92, df_num=1
# ssr based chi2 test:   chi2=-0.0000 , p=1.0000  , df=1
# likelihood ratio test: chi2=-0.0000 , p=1.0000  , df=1
# parameter F test:         F=247.2735, p=0.0000  , df_denom=92, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.0000  , p=1.0000  , df_denom=90, df_num=2
# ssr based chi2 test:   chi2=0.0000  , p=1.0000  , df=2
# likelihood ratio test: chi2=-0.0000 , p=1.0000  , df=2
# parameter F test:         F=123.2064, p=0.0000  , df_denom=90, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.0000  , p=1.0000  , df_denom=88, df_num=3
# ssr based chi2 test:   chi2=0.0000  , p=1.0000  , df=3
# likelihood ratio test: chi2=-0.0000 , p=1.0000  , df=3
# parameter F test:         F=81.8176 , p=0.0000  , df_denom=88, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.0000  , p=1.0000  , df_denom=86, df_num=4
# ssr based chi2 test:   chi2=0.0000  , p=1.0000  , df=4
# likelihood ratio test: chi2=-0.0000 , p=1.0000  , df=4
# parameter F test:         F=60.8201 , p=0.0000  , df_denom=86, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.0000  , p=1.0000  , df_denom=84, df_num=5
# ssr based chi2 test:   chi2=0.0000  , p=1.0000  , df=5
# likelihood ratio test: chi2=-0.0000 , p=1.0000  , df=5
# parameter F test:         F=48.0168 , p=0.0000  , df_denom=84, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=-0.0000 , p=1.0000  , df_denom=82, df_num=6
# ssr based chi2 test:   chi2=-0.0000 , p=1.0000  , df=6
# likelihood ratio test: chi2=-0.0000 , p=1.0000  , df=6
# parameter F test:         F=38.8126 , p=0.0000  , df_denom=82, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.0000  , p=1.0000  , df_denom=80, df_num=7
# ssr based chi2 test:   chi2=0.0000  , p=1.0000  , df=7
# likelihood ratio test: chi2=-0.0000 , p=1.0000  , df=7
# parameter F test:         F=32.1493 , p=0.0000  , df_denom=80, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.0000  , p=1.0000  , df_denom=78, df_num=8
# ssr based chi2 test:   chi2=0.0000  , p=1.0000  , df=8
# likelihood ratio test: chi2=-0.0000 , p=1.0000  , df=8
# parameter F test:         F=27.1703 , p=0.0000  , df_denom=78, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=-0.0000 , p=1.0000  , df_denom=76, df_num=9
# ssr based chi2 test:   chi2=-0.0000 , p=1.0000  , df=9
# likelihood ratio test: chi2=-0.0000 , p=1.0000  , df=9
# parameter F test:         F=23.2610 , p=0.0000  , df_denom=76, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.0000  , p=1.0000  , df_denom=74, df_num=10
# ssr based chi2 test:   chi2=0.0000  , p=1.0000  , df=10
# likelihood ratio test: chi2=-0.0000 , p=1.0000  , df=10
# parameter F test:         F=20.0511 , p=0.0000  , df_denom=74, df_num=10
#
# Granger Causality
# number of lags (no zero) 11
# ssr based F test:         F=0.0000  , p=1.0000  , df_denom=72, df_num=11
# ssr based chi2 test:   chi2=0.0000  , p=1.0000  , df=11
# likelihood ratio test: chi2=-0.0000 , p=1.0000  , df=11
# parameter F test:         F=17.3683 , p=0.0000  , df_denom=72, df_num=11
#
# Granger Causality
# number of lags (no zero) 12
# ssr based F test:         F=-0.0000 , p=1.0000  , df_denom=70, df_num=12
# ssr based chi2 test:   chi2=-0.0000 , p=1.0000  , df=12
# likelihood ratio test: chi2=-0.0000 , p=1.0000  , df=12
# parameter F test:         F=15.1571 , p=0.0000  , df_denom=70, df_num=12
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.5333  , p=0.2188  , df_denom=91, df_num=1
# ssr based chi2 test:   chi2=1.5838  , p=0.2082  , df=1
# likelihood ratio test: chi2=1.5706  , p=0.2101  , df=1
# parameter F test:         F=1.5333  , p=0.2188  , df_denom=91, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.1166  , p=0.8901  , df_denom=88, df_num=2
# ssr based chi2 test:   chi2=0.2465  , p=0.8841  , df=2
# likelihood ratio test: chi2=0.2461  , p=0.8842  , df=2
# parameter F test:         F=0.1166  , p=0.8901  , df_denom=88, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.0917  , p=0.9644  , df_denom=85, df_num=3
# ssr based chi2 test:   chi2=0.2978  , p=0.9604  , df=3
# likelihood ratio test: chi2=0.2974  , p=0.9605  , df=3
# parameter F test:         F=0.0917  , p=0.9644  , df_denom=85, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.0505  , p=0.9951  , df_denom=82, df_num=4
# ssr based chi2 test:   chi2=0.2241  , p=0.9942  , df=4
# likelihood ratio test: chi2=0.2238  , p=0.9942  , df=4
# parameter F test:         F=0.0505  , p=0.9951  , df_denom=82, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.0889  , p=0.9938  , df_denom=79, df_num=5
# ssr based chi2 test:   chi2=0.5063  , p=0.9919  , df=5
# likelihood ratio test: chi2=0.5049  , p=0.9919  , df=5
# parameter F test:         F=0.0889  , p=0.9938  , df_denom=79, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.0729  , p=0.9984  , df_denom=76, df_num=6
# ssr based chi2 test:   chi2=0.5121  , p=0.9977  , df=6
# likelihood ratio test: chi2=0.5106  , p=0.9977  , df=6
# parameter F test:         F=0.0729  , p=0.9984  , df_denom=76, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.0614  , p=0.9996  , df_denom=73, df_num=7
# ssr based chi2 test:   chi2=0.5181  , p=0.9994  , df=7
# likelihood ratio test: chi2=0.5166  , p=0.9994  , df=7
# parameter F test:         F=0.0614  , p=0.9996  , df_denom=73, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.1009  , p=0.9991  , df_denom=70, df_num=8
# ssr based chi2 test:   chi2=1.0034  , p=0.9982  , df=8
# likelihood ratio test: chi2=0.9976  , p=0.9983  , df=8
# parameter F test:         F=0.1009  , p=0.9991  , df_denom=70, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.1543  , p=0.3385  , df_denom=67, df_num=9
# ssr based chi2 test:   chi2=13.3343 , p=0.1481  , df=9
# likelihood ratio test: chi2=12.3963 , p=0.1919  , df=9
# parameter F test:         F=1.1543  , p=0.3385  , df_denom=67, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.1957  , p=0.3108  , df_denom=64, df_num=10
# ssr based chi2 test:   chi2=15.8798 , p=0.1031  , df=10
# likelihood ratio test: chi2=14.5587 , p=0.1490  , df=10
# parameter F test:         F=1.1957  , p=0.3108  , df_denom=64, df_num=10
#
# Granger Causality
# number of lags (no zero) 11
# ssr based F test:         F=1.6737  , p=0.1012  , df_denom=61, df_num=11
# ssr based chi2 test:   chi2=25.3527 , p=0.0081  , df=11
# likelihood ratio test: chi2=22.1560 , p=0.0232  , df=11
# parameter F test:         F=1.6737  , p=0.1012  , df_denom=61, df_num=11
#
# Granger Causality
# number of lags (no zero) 12
# ssr based F test:         F=3.2817  , p=0.0012  , df_denom=58, df_num=12
# ssr based chi2 test:   chi2=56.3545 , p=0.0000  , df=12
# likelihood ratio test: chi2=43.0090 , p=0.0000  , df=12
# parameter F test:         F=3.2817  , p=0.0012  , df_denom=58, df_num=12
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.6964  , p=0.4062  , df_denom=91, df_num=1
# ssr based chi2 test:   chi2=0.7194  , p=0.3963  , df=1
# likelihood ratio test: chi2=0.7166  , p=0.3972  , df=1
# parameter F test:         F=0.6964  , p=0.4062  , df_denom=91, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.3925  , p=0.6765  , df_denom=88, df_num=2
# ssr based chi2 test:   chi2=0.8297  , p=0.6605  , df=2
# likelihood ratio test: chi2=0.8260  , p=0.6617  , df=2
# parameter F test:         F=0.3925  , p=0.6765  , df_denom=88, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.3415  , p=0.7954  , df_denom=85, df_num=3
# ssr based chi2 test:   chi2=1.1087  , p=0.7750  , df=3
# likelihood ratio test: chi2=1.1021  , p=0.7766  , df=3
# parameter F test:         F=0.3415  , p=0.7954  , df_denom=85, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.2557  , p=0.9054  , df_denom=82, df_num=4
# ssr based chi2 test:   chi2=1.1349  , p=0.8887  , df=4
# likelihood ratio test: chi2=1.1278  , p=0.8898  , df=4
# parameter F test:         F=0.2557  , p=0.9054  , df_denom=82, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.1540  , p=0.3393  , df_denom=79, df_num=5
# ssr based chi2 test:   chi2=6.5733  , p=0.2544  , df=5
# likelihood ratio test: chi2=6.3443  , p=0.2741  , df=5
# parameter F test:         F=1.1540  , p=0.3393  , df_denom=79, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.2894  , p=0.9402  , df_denom=76, df_num=6
# ssr based chi2 test:   chi2=2.0337  , p=0.9166  , df=6
# likelihood ratio test: chi2=2.0108  , p=0.9187  , df=6
# parameter F test:         F=0.2894  , p=0.9402  , df_denom=76, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.1994  , p=0.9847  , df_denom=73, df_num=7
# ssr based chi2 test:   chi2=1.6823  , p=0.9753  , df=7
# likelihood ratio test: chi2=1.6664  , p=0.9760  , df=7
# parameter F test:         F=0.1994  , p=0.9847  , df_denom=73, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.1944  , p=0.9909  , df_denom=70, df_num=8
# ssr based chi2 test:   chi2=1.9324  , p=0.9830  , df=8
# likelihood ratio test: chi2=1.9112  , p=0.9836  , df=8
# parameter F test:         F=0.1944  , p=0.9909  , df_denom=70, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.3633  , p=0.9485  , df_denom=67, df_num=9
# ssr based chi2 test:   chi2=4.1974  , p=0.8979  , df=9
# likelihood ratio test: chi2=4.0982  , p=0.9048  , df=9
# parameter F test:         F=0.3633  , p=0.9485  , df_denom=67, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.3931  , p=0.9451  , df_denom=64, df_num=10
# ssr based chi2 test:   chi2=5.2210  , p=0.8759  , df=10
# likelihood ratio test: chi2=5.0669  , p=0.8867  , df=10
# parameter F test:         F=0.3931  , p=0.9451  , df_denom=64, df_num=10
#
# Granger Causality
# number of lags (no zero) 11
# ssr based F test:         F=0.4798  , p=0.9088  , df_denom=61, df_num=11
# ssr based chi2 test:   chi2=7.2678  , p=0.7770  , df=11
# likelihood ratio test: chi2=6.9704  , p=0.8015  , df=11
# parameter F test:         F=0.4798  , p=0.9088  , df_denom=61, df_num=11
#
# Granger Causality
# number of lags (no zero) 12
# ssr based F test:         F=0.3706  , p=0.9688  , df_denom=58, df_num=12
# ssr based chi2 test:   chi2=6.3648  , p=0.8966  , df=12
# likelihood ratio test: chi2=6.1325  , p=0.9093  , df=12
# parameter F test:         F=0.3706  , p=0.9688  , df_denom=58, df_num=12
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.2536  , p=0.6158  , df_denom=91, df_num=1
# ssr based chi2 test:   chi2=0.2619  , p=0.6088  , df=1
# likelihood ratio test: chi2=0.2616  , p=0.6090  , df=1
# parameter F test:         F=0.2536  , p=0.6158  , df_denom=91, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.1037  , p=0.9016  , df_denom=88, df_num=2
# ssr based chi2 test:   chi2=0.2193  , p=0.8962  , df=2
# likelihood ratio test: chi2=0.2190  , p=0.8963  , df=2
# parameter F test:         F=0.1037  , p=0.9016  , df_denom=88, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.0724  , p=0.9746  , df_denom=85, df_num=3
# ssr based chi2 test:   chi2=0.2351  , p=0.9717  , df=3
# likelihood ratio test: chi2=0.2348  , p=0.9718  , df=3
# parameter F test:         F=0.0724  , p=0.9746  , df_denom=85, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.0791  , p=0.9885  , df_denom=82, df_num=4
# ssr based chi2 test:   chi2=0.3510  , p=0.9863  , df=4
# likelihood ratio test: chi2=0.3504  , p=0.9863  , df=4
# parameter F test:         F=0.0791  , p=0.9885  , df_denom=82, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.1542  , p=0.9782  , df_denom=79, df_num=5
# ssr based chi2 test:   chi2=0.8786  , p=0.9718  , df=5
# likelihood ratio test: chi2=0.8743  , p=0.9721  , df=5
# parameter F test:         F=0.1542  , p=0.9782  , df_denom=79, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.1692  , p=0.9842  , df_denom=76, df_num=6
# ssr based chi2 test:   chi2=1.1892  , p=0.9774  , df=6
# likelihood ratio test: chi2=1.1813  , p=0.9778  , df=6
# parameter F test:         F=0.1692  , p=0.9842  , df_denom=76, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.1607  , p=0.9919  , df_denom=73, df_num=7
# ssr based chi2 test:   chi2=1.3564  , p=0.9869  , df=7
# likelihood ratio test: chi2=1.3460  , p=0.9872  , df=7
# parameter F test:         F=0.1607  , p=0.9919  , df_denom=73, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.1615  , p=0.9951  , df_denom=70, df_num=8
# ssr based chi2 test:   chi2=1.6054  , p=0.9908  , df=8
# likelihood ratio test: chi2=1.5908  , p=0.9911  , df=8
# parameter F test:         F=0.1615  , p=0.9951  , df_denom=70, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.1628  , p=0.9970  , df_denom=67, df_num=9
# ssr based chi2 test:   chi2=1.8804  , p=0.9932  , df=9
# likelihood ratio test: chi2=1.8602  , p=0.9935  , df=9
# parameter F test:         F=0.1628  , p=0.9970  , df_denom=67, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.1763  , p=0.9974  , df_denom=64, df_num=10
# ssr based chi2 test:   chi2=2.3409  , p=0.9930  , df=10
# likelihood ratio test: chi2=2.3092  , p=0.9934  , df=10
# parameter F test:         F=0.1763  , p=0.9974  , df_denom=64, df_num=10
#
# Granger Causality
# number of lags (no zero) 11
# ssr based F test:         F=0.1633  , p=0.9988  , df_denom=61, df_num=11
# ssr based chi2 test:   chi2=2.4741  , p=0.9960  , df=11
# likelihood ratio test: chi2=2.4383  , p=0.9963  , df=11
# parameter F test:         F=0.1633  , p=0.9988  , df_denom=61, df_num=11
#
# Granger Causality
# number of lags (no zero) 12
# ssr based F test:         F=0.2082  , p=0.9975  , df_denom=58, df_num=12
# ssr based chi2 test:   chi2=3.5747  , p=0.9899  , df=12
# likelihood ratio test: chi2=3.4999  , p=0.9909  , df=12
# parameter F test:         F=0.2082  , p=0.9975  , df_denom=58, df_num=12
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=2.8798  , p=0.0931  , df_denom=91, df_num=1
# ssr based chi2 test:   chi2=2.9747  , p=0.0846  , df=1
# likelihood ratio test: chi2=2.9286  , p=0.0870  , df=1
# parameter F test:         F=2.8798  , p=0.0931  , df_denom=91, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.3559  , p=0.2630  , df_denom=88, df_num=2
# ssr based chi2 test:   chi2=2.8659  , p=0.2386  , df=2
# likelihood ratio test: chi2=2.8226  , p=0.2438  , df=2
# parameter F test:         F=1.3559  , p=0.2630  , df_denom=88, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.8923  , p=0.4486  , df_denom=85, df_num=3
# ssr based chi2 test:   chi2=2.8972  , p=0.4077  , df=3
# likelihood ratio test: chi2=2.8525  , p=0.4149  , df=3
# parameter F test:         F=0.8923  , p=0.4486  , df_denom=85, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.7002  , p=0.5940  , df_denom=82, df_num=4
# ssr based chi2 test:   chi2=3.1083  , p=0.5399  , df=4
# likelihood ratio test: chi2=3.0564  , p=0.5484  , df=4
# parameter F test:         F=0.7002  , p=0.5940  , df_denom=82, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.6122  , p=0.6908  , df_denom=79, df_num=5
# ssr based chi2 test:   chi2=3.4872  , p=0.6253  , df=5
# likelihood ratio test: chi2=3.4213  , p=0.6353  , df=5
# parameter F test:         F=0.6122  , p=0.6908  , df_denom=79, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.5700  , p=0.7530  , df_denom=76, df_num=6
# ssr based chi2 test:   chi2=4.0049  , p=0.6760  , df=6
# likelihood ratio test: chi2=3.9174  , p=0.6879  , df=6
# parameter F test:         F=0.5700  , p=0.7530  , df_denom=76, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.4821  , p=0.8446  , df_denom=73, df_num=7
# ssr based chi2 test:   chi2=4.0679  , p=0.7719  , df=7
# likelihood ratio test: chi2=3.9767  , p=0.7825  , df=7
# parameter F test:         F=0.4821  , p=0.8446  , df_denom=73, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.3944  , p=0.9201  , df_denom=70, df_num=8
# ssr based chi2 test:   chi2=3.9211  , p=0.8642  , df=8
# likelihood ratio test: chi2=3.8353  , p=0.8717  , df=8
# parameter F test:         F=0.3944  , p=0.9201  , df_denom=70, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.3901  , p=0.9358  , df_denom=67, df_num=9
# ssr based chi2 test:   chi2=4.5067  , p=0.8750  , df=9
# likelihood ratio test: chi2=4.3926  , p=0.8837  , df=9
# parameter F test:         F=0.3901  , p=0.9358  , df_denom=67, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.3659  , p=0.9569  , df_denom=64, df_num=10
# ssr based chi2 test:   chi2=4.8597  , p=0.9004  , df=10
# likelihood ratio test: chi2=4.7258  , p=0.9087  , df=10
# parameter F test:         F=0.3659  , p=0.9569  , df_denom=64, df_num=10
#
# Granger Causality
# number of lags (no zero) 11
# ssr based F test:         F=0.3262  , p=0.9769  , df_denom=61, df_num=11
# ssr based chi2 test:   chi2=4.9419  , p=0.9339  , df=11
# likelihood ratio test: chi2=4.8020  , p=0.9404  , df=11
# parameter F test:         F=0.3262  , p=0.9769  , df_denom=61, df_num=11
#
# Granger Causality
# number of lags (no zero) 12
# ssr based F test:         F=0.2941  , p=0.9881  , df_denom=58, df_num=12
# ssr based chi2 test:   chi2=5.0508  , p=0.9563  , df=12
# likelihood ratio test: chi2=4.9031  , p=0.9611  , df=12
# parameter F test:         F=0.2941  , p=0.9881  , df_denom=58, df_num=12
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.3347  , p=0.5643  , df_denom=91, df_num=1
# ssr based chi2 test:   chi2=0.3458  , p=0.5565  , df=1
# likelihood ratio test: chi2=0.3451  , p=0.5569  , df=1
# parameter F test:         F=0.3347  , p=0.5643  , df_denom=91, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.9405  , p=0.3943  , df_denom=88, df_num=2
# ssr based chi2 test:   chi2=1.9879  , p=0.3701  , df=2
# likelihood ratio test: chi2=1.9669  , p=0.3740  , df=2
# parameter F test:         F=0.9405  , p=0.3943  , df_denom=88, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.8448  , p=0.4732  , df_denom=85, df_num=3
# ssr based chi2 test:   chi2=2.7430  , p=0.4330  , df=3
# likelihood ratio test: chi2=2.7029  , p=0.4397  , df=3
# parameter F test:         F=0.8448  , p=0.4732  , df_denom=85, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.6608  , p=0.6210  , df_denom=82, df_num=4
# ssr based chi2 test:   chi2=2.9333  , p=0.5691  , df=4
# likelihood ratio test: chi2=2.8870  , p=0.5769  , df=4
# parameter F test:         F=0.6608  , p=0.6210  , df_denom=82, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.5349  , p=0.7492  , df_denom=79, df_num=5
# ssr based chi2 test:   chi2=3.0469  , p=0.6928  , df=5
# likelihood ratio test: chi2=2.9965  , p=0.7005  , df=5
# parameter F test:         F=0.5349  , p=0.7492  , df_denom=79, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.6354  , p=0.7015  , df_denom=76, df_num=6
# ssr based chi2 test:   chi2=4.4642  , p=0.6141  , df=6
# likelihood ratio test: chi2=4.3559  , p=0.6286  , df=6
# parameter F test:         F=0.6354  , p=0.7015  , df_denom=76, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.5329  , p=0.8068  , df_denom=73, df_num=7
# ssr based chi2 test:   chi2=4.4970  , p=0.7211  , df=7
# likelihood ratio test: chi2=4.3859  , p=0.7344  , df=7
# parameter F test:         F=0.5329  , p=0.8068  , df_denom=73, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.5758  , p=0.7943  , df_denom=70, df_num=8
# ssr based chi2 test:   chi2=5.7256  , p=0.6779  , df=8
# likelihood ratio test: chi2=5.5450  , p=0.6980  , df=8
# parameter F test:         F=0.5758  , p=0.7943  , df_denom=70, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.5960  , p=0.7958  , df_denom=67, df_num=9
# ssr based chi2 test:   chi2=6.8854  , p=0.6490  , df=9
# likelihood ratio test: chi2=6.6237  , p=0.6762  , df=9
# parameter F test:         F=0.5960  , p=0.7958  , df_denom=67, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.7107  , p=0.7112  , df_denom=64, df_num=10
# ssr based chi2 test:   chi2=9.4388  , p=0.4910  , df=10
# likelihood ratio test: chi2=8.9506  , p=0.5368  , df=10
# parameter F test:         F=0.7107  , p=0.7112  , df_denom=64, df_num=10
#
# Granger Causality
# number of lags (no zero) 11
# ssr based F test:         F=0.7041  , p=0.7298  , df_denom=61, df_num=11
# ssr based chi2 test:   chi2=10.6654 , p=0.4717  , df=11
# likelihood ratio test: chi2=10.0407 , p=0.5267  , df=11
# parameter F test:         F=0.7041  , p=0.7298  , df_denom=61, df_num=11
#
# Granger Causality
# number of lags (no zero) 12
# ssr based F test:         F=0.7242  , p=0.7220  , df_denom=58, df_num=12
# ssr based chi2 test:   chi2=12.4371 , p=0.4112  , df=12
# likelihood ratio test: chi2=11.5890 , p=0.4792  , df=12
# parameter F test:         F=0.7242  , p=0.7220  , df_denom=58, df_num=12
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[108], line 1
# ----> 1 grangers_causation_matrix(df, variables = df.columns)
#
# Cell In[105], line 16, in grangers_causation_matrix(data, variables, test, verbose)
#      14 for c in df.columns:
#      15     for r in df.index:
# ---> 16         test_result = grangercausalitytests(data[[r, c]], maxlag=maxlag)
#      17         p_values = [round(test_result[i+1][0][test][1],4) for i in range(maxlag)]
#      18         if verbose: print(f'Y = {r}, X = {c}, P Values = {p_values}')
#
# File D:\anaconda3\Lib\site-packages\statsmodels\tsa\stattools.py:1484, in grangercausalitytests(x, maxlag, addconst, verbose)
#    1482 x = array_like(x, "x", ndim=2)
#    1483 if not np.isfinite(x).all():
# -> 1484     raise ValueError("x contains NaN or inf values.")
#    1485 addconst = bool_like(addconst, "addconst")
#    1486 if verbose is not None:
#
# ValueError: x contains NaN or inf values.

# %%
cointegration_test(df)
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# Cell In[109], line 1
# ----> 1 cointegration_test(df)
#
# Cell In[103], line 3, in cointegration_test(df, alpha)
#       1 def cointegration_test(df, alpha=0.05):
#       2     """Perform Johanson's Cointegration Test and Report Summary"""
# ----> 3     out = coint_johansen(df,-1,5)
#       4     d = {'0.90':0, '0.95':1, '0.99':2}
#       5     traces = out.lr1
#
# File D:\anaconda3\Lib\site-packages\statsmodels\tsa\vector_ar\vecm.py:694, in coint_johansen(endog, det_order, k_ar_diff)
#     691 dx = dx[k_ar_diff:]
#     693 dx = detrend(dx, f)
# --> 694 r0t = resid(dx, z)
#     695 # GH 5731, [:-0] does not work, need [:t-0]
#     696 lx = endog[: (endog.shape[0] - k_ar_diff)]
#
# File D:\anaconda3\Lib\site-packages\statsmodels\tsa\vector_ar\vecm.py:673, in coint_johansen.<locals>.resid(y, x)
#     671 if x.size == 0:
#     672     return y
# --> 673 r = y - np.dot(x, np.dot(np.linalg.pinv(x), y))
#     674 return r
#
# File <__array_function__ internals>:200, in pinv(*args, **kwargs)
#
# File D:\anaconda3\Lib\site-packages\numpy\linalg\linalg.py:1983, in pinv(a, rcond, hermitian)
#    1981     return wrap(res)
#    1982 a = a.conjugate()
# -> 1983 u, s, vt = svd(a, full_matrices=False, hermitian=hermitian)
#    1985 # discard small singular values
#    1986 cutoff = rcond[..., newaxis] * amax(s, axis=-1, keepdims=True)
#
# File <__array_function__ internals>:200, in svd(*args, **kwargs)
#
# File D:\anaconda3\Lib\site-packages\numpy\linalg\linalg.py:1642, in svd(a, full_matrices, compute_uv, hermitian)
#    1639         gufunc = _umath_linalg.svd_n_s
#    1641 signature = 'D->DdD' if isComplexType(t) else 'd->ddd'
# -> 1642 u, s, vh = gufunc(a, signature=signature, extobj=extobj)
#    1643 u = u.astype(result_t, copy=False)
#    1644 s = s.astype(_realType(result_t), copy=False)
#
# File D:\anaconda3\Lib\site-packages\numpy\linalg\linalg.py:98, in _raise_linalgerror_svd_nonconvergence(err, flag)
#      97 def _raise_linalgerror_svd_nonconvergence(err, flag):
# ---> 98     raise LinAlgError("SVD did not converge")
#
# LinAlgError: SVD did not converge

# %% [markdown]
# # split dataset

# %%
pp = -12
df_train, df_test = df[:pp], df[pp:]
df_test = df_test.diff().diff().dropna()

# %% [markdown]
# # check for stationary

# %%
df_differenced = df_train.dropna()
for name, column in df_differenced.items():
    adfuller_test(column, name=column.name)
    print('\n')
# Out:
#     Augmented Dickey-Fuller Test on "us bankruptcy"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -2.8244
#  No. Lags Chosen       = 0
#  Critical value 1%     = -3.513
#  Critical value 5%     = -2.897
#  Critical value 10%    = -2.586
#  => P-Value = 0.0549. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#     Augmented Dickey-Fuller Test on "EFFR"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -3.9522
#  No. Lags Chosen       = 3
#  Critical value 1%     = -3.516
#  Critical value 5%     = -2.899
#  Critical value 10%    = -2.587
#  => P-Value = 0.0017. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "us employment cost index"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = 0.58
#  No. Lags Chosen       = 7
#  Critical value 1%     = -3.521
#  Critical value 5%     = -2.901
#  Critical value 10%    = -2.588
#  => P-Value = 0.9871. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#     Augmented Dickey-Fuller Test on "GDP(Billions)"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -0.0741
#  No. Lags Chosen       = 1
#  Critical value 1%     = -3.514
#  Critical value 5%     = -2.898
#  Critical value 10%    = -2.586
#  => P-Value = 0.952. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#     Augmented Dickey-Fuller Test on "real GDP(Billions)"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -0.6374
#  No. Lags Chosen       = 1
#  Critical value 1%     = -3.514
#  Critical value 5%     = -2.898
#  Critical value 10%    = -2.586
#  => P-Value = 0.8623. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#     Augmented Dickey-Fuller Test on "us unemployment rate"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -2.0041
#  No. Lags Chosen       = 2
#  Critical value 1%     = -3.515
#  Critical value 5%     = -2.898
#  Critical value 10%    = -2.586
#  => P-Value = 0.2848. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#     Augmented Dickey-Fuller Test on "us homeownership rate"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -1.3533
#  No. Lags Chosen       = 4
#  Critical value 1%     = -3.517
#  Critical value 5%     = -2.899
#  Critical value 10%    = -2.587
#  => P-Value = 0.6044. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#     Augmented Dickey-Fuller Test on "Interest Rates: Long-Term Government Bond Yields: 10-Year: Main (Including Benchmark) for United States"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -1.1523
#  No. Lags Chosen       = 3
#  Critical value 1%     = -3.516
#  Critical value 5%     = -2.899
#  Critical value 10%    = -2.587
#  => P-Value = 0.6938. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.

# %% [markdown]
# # use differencing to make it stationary

# %%
df_differenced = df_train.diff().diff().dropna()
for name, column in df_differenced.items():
    adfuller_test(column, name=column.name)
    print('\n')
# Out:
#     Augmented Dickey-Fuller Test on "us bankruptcy"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -6.6173
#  No. Lags Chosen       = 5
#  Critical value 1%     = -3.521
#  Critical value 5%     = -2.901
#  Critical value 10%    = -2.588
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "EFFR"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -8.2898
#  No. Lags Chosen       = 1
#  Critical value 1%     = -3.516
#  Critical value 5%     = -2.899
#  Critical value 10%    = -2.587
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "us employment cost index"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -9.6129
#  No. Lags Chosen       = 5
#  Critical value 1%     = -3.521
#  Critical value 5%     = -2.901
#  Critical value 10%    = -2.588
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "GDP(Billions)"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -6.2308
#  No. Lags Chosen       = 3
#  Critical value 1%     = -3.518
#  Critical value 5%     = -2.9
#  Critical value 10%    = -2.587
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "real GDP(Billions)"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -6.2583
#  No. Lags Chosen       = 4
#  Critical value 1%     = -3.519
#  Critical value 5%     = -2.9
#  Critical value 10%    = -2.587
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "us unemployment rate"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -19.8284
#  No. Lags Chosen       = 0
#  Critical value 1%     = -3.515
#  Critical value 5%     = -2.898
#  Critical value 10%    = -2.586
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "us homeownership rate"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -10.1167
#  No. Lags Chosen       = 2
#  Critical value 1%     = -3.517
#  Critical value 5%     = -2.899
#  Critical value 10%    = -2.587
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "Interest Rates: Long-Term Government Bond Yields: 10-Year: Main (Including Benchmark) for United States"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -7.5089
#  No. Lags Chosen       = 3
#  Critical value 1%     = -3.518
#  Critical value 5%     = -2.9
#  Critical value 10%    = -2.587
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.

# %% [markdown]
# # Build model

# %%
model = VAR(df_differenced)
# Out:
# D:\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency Q-DEC will be used.
#   self._init_dates(dates, freq)

# %% [markdown]
# # select proper order

# %%
sorted_order = model.select_order(maxlags=8)
sorted_order.summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
model = VAR(df_differenced)
# Out:
# D:\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency Q-DEC will be used.
#   self._init_dates(dates, freq)

# %%
model_fitted = model.fit(8)

# %%
model_fitted.summary()
# Out:
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Mon, 20, Nov, 2023
# Time:                     10:40:46
# --------------------------------------------------------------------
# No. of Equations:         8.00000    BIC:                    33.3835
# Nobs:                     73.0000    HQIC:                   23.5700
# Log likelihood:          -931.639    FPE:                1.31706e+11
# AIC:                      17.0679    Det(Omega_mle):     8.07525e+08
# --------------------------------------------------------------------
# Results for equation us bankruptcy
# =============================================================================================================================================================================
#                                                                                                                 coefficient       std. error           t-stat            prob
# -----------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# const                                                                                                           2741.836862      8849.087950            0.310           0.757
# L1.us bankruptcy                                                                                                  -0.302047         0.331067           -0.912           0.362
# L1.EFFR                                                                                                      -117066.663893    115566.746514           -1.013           0.311
# L1.us employment cost index                                                                                     8590.653803    193113.353066            0.044           0.965
# L1.GDP(Billions)                                                                                               -1152.982940       548.073449           -2.104           0.035
# L1.real GDP(Billions)                                                                                           1963.518431       805.589670            2.437           0.015
# L1.us unemployment rate                                                                                       150482.679762     66917.389052            2.249           0.025
# L1.us homeownership rate                                                                                     -114956.399222     72656.728398           -1.582           0.114
# L1.Interest Rates: Long-Term Government Bond Yields: 10-Year: Main (Including Benchmark) for United States     -9437.482885     52275.109656           -0.181           0.857
# L2.us bankruptcy                                                                                                  -0.990062         0.317283           -3.120           0.002
# L2.EFFR                                                                                                       -41040.322058    100218.968105           -0.410           0.682
# L2.us employment cost index                                                                                  -174205.353457    168267.961794           -1.035           0.301
# L2.GDP(Billions)                                                                                                -737.384156       621.065118           -1.187           0.235
# L2.real GDP(Billions)                                                                                           1239.389171       775.021076            1.599           0.110
# L2.us unemployment rate                                                                                       340636.731091    202260.916727            1.684           0.092
# L2.us homeownership rate                                                                                       30220.230065    104432.371702            0.289           0.772
# L2.Interest Rates: Long-Term Government Bond Yields: 10-Year: Main (Including Benchmark) for United States    -19721.625487     60041.530077           -0.328           0.743
# L3.us bankruptcy                                                                                                  -1.089667         0.597506           -1.824           0.068
# L3.EFFR                                                                                                       -47596.896248     80257.070109           -0.593           0.553
# L3.us employment cost index                                                                                  -355403.786273    133472.610095           -2.663           0.008
# L3.GDP(Billions)                                                                                                -138.784668       632.556758           -0.219           0.826
# L3.real GDP(Billions)                                                                                            476.594760       749.714495            0.636           0.525
# L3.us unemployment rate                                                                                       -50265.729356    237211.136249           -0.212           0.832
# L3.us homeownership rate                                                                                      123360.069832    129125.560836            0.955           0.339
# L3.Interest Rates: Long-Term Government Bond Yields: 10-Year: Main (Including Benchmark) for United States     -1471.191399     75466.011003           -0.019           0.984
# L4.us bankruptcy                                                                                                  -0.223689         0.443034           -0.505           0.614
# L4.EFFR                                                                                                       -44543.498332     97509.777648           -0.457           0.648
# L4.us employment cost index                                                                                    78163.580432    149050.107408            0.524           0.600
# L4.GDP(Billions)                                                                                                -387.302570       691.744147           -0.560           0.576
# L4.real GDP(Billions)                                                                                           1171.007242       732.964497            1.598           0.110
# L4.us unemployment rate                                                                                        24296.583941    173599.178340            0.140           0.889
# L4.us homeownership rate                                                                                      290598.371547    164108.056057            1.771           0.077
# L4.Interest Rates: Long-Term Government Bond Yields: 10-Year: Main (Including Benchmark) for United States    -23827.470507     90330.040184           -0.264           0.792
# L5.us bankruptcy                                                                                                  -0.350390         0.442733           -0.791           0.429
# L5.EFFR                                                                                                        -2831.166050     94333.771047           -0.030           0.976
# L5.us employment cost index                                                                                    10635.739330      9163.960661            1.161           0.246
# L5.GDP(Billions)                                                                                               -1039.625204       784.906877           -1.325           0.185
# L5.real GDP(Billions)                                                                                           1223.548656      1294.754146            0.945           0.345
# L5.us unemployment rate                                                                                       158079.503251    214783.029833            0.736           0.462
# L5.us homeownership rate                                                                                       76021.876396    131724.735376            0.577           0.564
# L5.Interest Rates: Long-Term Government Bond Yields: 10-Year: Main (Including Benchmark) for United
Interest Rates: Long-Term Government Bond Yields: 10-Year: Main (Including Benchmark) for United States        -0.292484         0.288844           -1.013           0.311
# =============================================================================================================================================================================
#
# Results for equation us employment cost index
# =============================================================================================================================================================================
#                                                                                                                 coefficient       std. error           t-stat            prob
# -----------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# const                                                                                                              0.008158         0.025527            0.320           0.749
# L1.us bankruptcy                                                                                                   0.000000         0.000001            0.000           1.000
# L1.EFFR                                                                                                           -0.488691         0.333382           -1.466           0.143
# L1.us employment cost index                                                                                       -1.112031         0.557085           -1.996           0.046
# L1.GDP(Billions)                                                                                                   0.000202         0.001581            0.128           0.898
# L1.real GDP(Billions)                                                                                              0.001625         0.002324            0.699           0.484
# L1.us unemployment rate                                                                                            0.269700         0.193040            1.397           0.162
# L1.us homeownership rate                                                                                           0.074736         0.209597            0.357           0.721
# L1.Interest Rates: Long-Term Government Bond Yields: 10-Year: Main (Including Benchmark) for United States         0.094885         0.150801            0.629           0.529
# L2.us bankruptcy                                                                                                  -0.000001         0.000001           -0.737           0.461
# L2.EFFR                                                                                                           -0.308485         0.289107           -1.067           0.286
# L2.us employment cost index                                                                                       -0.250663         0.485412           -0.516           0.606
# L2.GDP(Billions)                                                                                                   0.000563         0.001792            0.314           0.753
# L2.real GDP(Billions)                                                                                              0.000508         0.002236            0.227           0.820
# L2.us unemployment rate                                                                                            0.084765         0.583473            0.145           0.884
# L2.us homeownership rate                                                                                          -0.029610         0.301262           -0.098           0.922
# L2.Interest Rates: Long-Term Government Bond Yields: 10-Year: Main (Including Benchmark) for United States        -0.029049         0.173205           -0.168           0.867
# L3.us bankruptcy                                                                                                  -0.000002         0.000002           -1.074           0.283
# L3.EFFR                                                                                                            0.162460         0.231522            0.702           0.483
# L3.us employment cost index                                                                                       -0.151589         0.385036           -0.394           0.694
# L3.GDP(Billions)                                                                                                   0.003272         0.001825            1.793           0.073
# L3.real GDP(Billions)                                                                                             -0.003482         0.002163           -1.610           0.107
# L3.us unemployment rate                                                                                            0.126277         0.684296            0.185           0.854
# L3.us homeownership rate                                                                                           0.465319         0.372496            1.249           0.212
# L3.Interest Rates: Long-Term Government Bond Yields: 10-Year: Main (Including Benchmark) for United States        -0.149320         0.217701           -0.686           0.493
# L4.us bankruptcy                                                                                                  -0.000001         0.000001           -0.422           0.673
# L4.EFFR                                                                                                            0.234360         0.281292            0.833           0.405
# L4.us employment cost index                                                                                       -0.445032         0.429973           -1.035           0.301
# L4.GDP(Billions)                                                                                                   0.000293         0.001996            0.147           0.883
# L4.real GDP(Billions)                                                                                              0.000171         0.002114            0.081           0.935
# L4.us unemployment rate                                                                                            0.370100         0.500791            0.739           0.460
# L4.us homeownership rate                                                                                           0.170604         0.473412            0.360           0.719
# L4.Interest Rates: Long-Term Government Bond Yields: 10-Year: Main (Including Benchmark) for United States         0.044948         0.260580            0.172           0.863
# L5.us bankruptcy                                                                                                   0.000000         0.000001            0.099           0.921
# L5.EFFR                                                                                                            0.224693         0.272130            0.826           0.409
# L5.us employment cost index                                                                                       -0.016478         0.026436           -0.623           0.533
# L5.GDP(Billions)                                                                                                  -0.000459         0.002264           -0.203           0.839
# L5.real GDP(Billions)                                                                                              0.002440         0.003735            0.653           0.514
# L5.us unemployment rate                                                                                            0.634039         0.619596            1.023           0.306
# L5.us homeownership rate                                                                                          -0.013933         0.379994           -0.037           0.971
# L5.Interest Rates: Long-Term Government Bond Yields: 10-Year: Main (Including Benchmark) for United States         0.081563         0.221764            0.368           0.713
# L6.us bankruptcy                                                                                                  -0.000001         0.000001           -0.736           0.462
# L6.EFFR                                                                                                            0.201893         0.239864            0.842           0.400
# L6.us employment cost index                                                                                       -0.036121         0.024296           -1.487           0.137
# L6.GDP(Billions)                                                                                                  -0.000339         0.001568           -0.216           0.829
# L6.real GDP(Billions)                                                                                              0.001547         0.001844            0.839           0.401
# L6.us unemployment rate                                                                                            0.074022         0.471009            0.157           0.875
# L6.us homeownership rate                                                                                          -0.003949         0.361361           -0.011           0.991
# L6.Interest Rates: Long-Term Government Bond Yields: 10-Year: Main (Including Benchmark) for United States         0.083792         0.249549            0.336           0.737
# L7.us bankruptcy                                                                                                  -0.000001         0.000001           -0.950           0.342
# L7.EFFR                                                                                                            0.048886         0.256120            0.191           0.849
# L7.us employment cost index                                                                                       -0.026678         0.030673           -0.870           0.384
# L7.GDP(Billions)                                                                                                   0.000799         0.001744            0.458           0.647
# L7.real GDP(Billions)                                                                                             -0.001160         0.001548           -0.749           0.454
# L7.us unemployment rate                                                                                           -0.446721         0.512254           -0.872           0.383
# L7.us homeownership rate                                                                                          -0.071373         0.308141           -0.232           0.817
# L7.Interest Rates: Long-Term Government Bond Yields: 10-Year: Main (Including Benchmark) for United States         0.259590         0.313976            0.827           0.408
# L8.us bankruptcy                                                                                                  -0.000000         0.000001           -0.363           0.717
# L8.EFFR                                                                                                           -0.217528         0.259391           -0.839           0.402
# L8.us employment cost index                                                                                       -0.010958         0.026018           -0.421           0.674
# L8.GDP(Billions)                                                                                                  -0.000994         0.001861           -0.534           0.593
# L8.real GDP(Billions)                                                                                              0.000380         0.001891            0.201           0.841
# L8.us unemployment rate                                                                                           -0.418090         0.494219           -0.846           0.398
# L8.us homeownership rate                                                                                          -0.241105         0.327512           -0.736           0.462
# L8.Interest Rates: Long-Term Government Bond Yields: 10-Year: Main (Including Benchmark) for United States         0.099198         0.168789            0.588           0.557
# =============================================================================================================================================================================
#
# Results for equation GDP(Billions)
# =============================================================================================================================================================================
#                                                                                                                 coefficient       std. error           t-stat            prob
# -----------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# const                                                                                                             -7.845944        32.217000           -0.244           0.808
# L1.us bankruptcy                                                                                                   0.000974         0.001205            0.808           0.419
# L1.EFFR                                                                                                          -25.290267       420.745489           -0.060           0.952
# L1.us employment cost index                                                                                     -901.873536       703.070517           -1.283           0.200
# L1.GDP(Billions)                                                                                                  -2.537045         1.995379           -1.271           0.204
# L1.real GDP(Billions)                                                                                              3.841968         2.932922            1.310           0.190
# L1.us unemployment rate                                                                                          497.342248       243.627085            2.041           0.041
# L1.us homeownership rate                                                                                         -83.230609       264.522379           -0.315           0.753
# L1.Interest Rates: Long-Term Government Bond Yields: 10-Year: Main (Including Benchmark) for United States       332.366083       190.318731            1.746           0.081
# L2.us bankruptcy                                                                                                   0.000757         0.001155            0.655           0.512
# L2.EFFR                                                                                                         -134.444885       364.868615           -0.368           0.713
# L2.us employment cost index                                                                                     -375.434125       612.615549           -0.613           0.540
# L2.GDP(Billions)                                                                                                  -3.052589         2.261121           -1.350           0.177
# L2.real GDP(Billions)                                                                                              3.751935         2.821630            1.330           0.184
# L2.us unemployment rate                                                                                         -151.223438       736.374181           -0.205           0.837
# L2.us homeownership rate                                                                                        -196.717219       380.208413           -0.517           0.605
# L2.Interest Rates: Long-Term Government Bond Yields: 10-Year: Main (Including Benchmark) for United
Interest Rates: Long-Term Government Bond Yields: 10-Year: Main (Including Benchmark) for United States        -0.307752         0.510870           -0.602           0.547
# L7.us bankruptcy                                                                                                  -0.000001         0.000002           -0.370           0.712
# L7.EFFR                                                                                                           -0.256244         0.524321           -0.489           0.625
# L7.us employment cost index                                                                                        0.095503         0.062792            1.521           0.128
# L7.GDP(Billions)                                                                                                   0.002222         0.003569            0.623           0.534
# L7.real GDP(Billions)                                                                                             -0.000719         0.003170           -0.227           0.820
# L7.us unemployment rate                                                                                            0.679465         1.048672            0.648           0.517
# L7.us homeownership rate                                                                                           0.091333         0.630818            0.145           0.885
# L7.Interest Rates: Long-Term Government Bond Yields: 10-Year: Main (Including Benchmark) for United States        -0.548050         0.642763           -0.853           0.394
# L8.us bankruptcy                                                                                                  -0.000002         0.000002           -1.140           0.254
# L8.EFFR                                                                                                            0.304245         0.531018            0.573           0.567
# L8.us employment cost index                                                                                        0.065736         0.053263            1.234           0.217
# L8.GDP(Billions)                                                                                                   0.002142         0.003810            0.562           0.574
# L8.real GDP(Billions)                                                                                             -0.002622         0.003872           -0.677           0.498
# L8.us unemployment rate                                                                                            1.092260         1.011752            1.080           0.280
# L8.us homeownership rate                                                                                           0.573202         0.670472            0.855           0.393
# L8.Interest Rates: Long-Term Government Bond Yields: 10-Year: Main (Including Benchmark) for United States        -0.387605         0.345540           -1.122           0.262
# =============================================================================================================================================================================
#
# Correlation matrix of residuals
#                                                                                                            us bankruptcy      EFFR  us employment cost index  GDP(Billions)  real GDP(Billions)  us unemployment rate  us homeownership rate  Interest Rates: Long-Term Government Bond Yields: 10-Year: Main (Including Benchmark) for United States
# us bankruptcy                                                                                                   1.000000 -0.546558                 -0.395743       0.170776            0.007115             -0.279288              -0.470754                                                                                                 0.133755
# EFFR                                                                                                           -0.546558  1.000000                 -0.349758      -0.179483           -0.068571              0.437090               0.560777                                                                                                 0.285029
# us employment cost index                                                                                       -0.395743 -0.349758                  1.000000       0.567187            0.604900             -0.578613              -0.406723                                                                                                -0.228469
# GDP(Billions)                                                                                                   0.170776 -0.179483                  0.567187       1.000000            0.977866             -0.923029              -0.531604                                                                                                 0.143937
# real GDP(Billions)                                                                                              0.007115 -0.068571                  0.604900       0.977866            1.000000             -0.907498              -0.448562                                                                                                 0.136294
# us unemployment rate                                                                                           -0.279288  0.437090                 -0.578613      -0.923029           -0.907498              1.000000               0.597290                                                                                                -0.092547
# us homeownership rate                                                                                          -0.470754  0.560777                 -0.406723      -0.531604           -0.448562              0.597290               1.000000                                                                                                -0.103232
# Interest Rates: Long-Term Government Bond Yields: 10-Year: Main (Including Benchmark) for United States         0.133755  0.285029                 -0.228469       0.143937            0.136294             -0.092547              -0.103232                                                                                                 1.000000

# %%
out = durbin_watson(model_fitted.resid)

# %%
for col, val in zip(df.columns, out):
    print(col, ':', round(val, 2))
# Out:
# us bankruptcy : 1.64
# EFFR : 2.65
# us employment cost index : 1.63
# GDP(Billions) : 1.12
# real GDP(Billions) : 1.1
# us unemployment rate : 1.36
# us homeownership rate : 1.69
# Interest Rates: Long-Term Government Bond Yields: 10-Year: Main (Including Benchmark) for United States : 1.34

# %%
lag_order = model_fitted.k_ar
print(lag_order)
forecast_input = df_differenced.values[-lag_order:]
# Out:
# 8

# %%
fc = model_fitted.forecast(y=forecast_input, steps=lag_order)
df_forecast = pd.DataFrame(forecast_input, index=df.index[-lag_order:], columns=df.columns + '_2d')

# %%
def invert_transformation(df_train, df_forecast, second_diff=False):
    """Revert back the differencing to get the forecast to original scale."""
    df_fc = df_forecast.copy()
    columns = df_train.columns
    for col in columns:        
        # Roll back 2nd Diff
        if second_diff:
            df_fc[str(col)+'_1d'] = (df_train[col].iloc[-1]-df_train[col].iloc[-2]) + df_fc[str(col)+'_2d'].cumsum()
        # Roll back 1st Diff
        df_fc[str(col)+'_forecast'] = df_train[col].iloc[-1] + df_fc[str(col)+'_1d'].cumsum()
    return df_fc

# %%
df_results = invert_transformation(df_train, df_forecast, second_diff=True)

# %%
df_results.head()
# Out:
#             us bankruptcy_2d  EFFR_2d  us employment cost index_2d  \
# date
# 2021-12-31            2798.0     0.19                -1.000000e-01
# 2022-03-31           19489.0    -0.18                -1.000000e-01
# 2022-06-30            5301.0    -0.17                -2.842171e-14
# 2022-09-30          -24904.0    -0.31                 3.000000e-01
# 2022-12-31           -4997.0    -0.15                -2.000000e-01
#
#             GDP(Billions)_2d  real GDP(Billions)_2d  us unemployment rate_2d  \
# date
# 2021-12-31           -98.681                -96.958                 0.190976
# 2022-03-31            67.129                 81.556                 0.014790
# 2022-06-30            94.376                 59.102                -0.301433
# 2022-09-30            28.865                 63.675                 0.285752
# 2022-12-31          -101.399                -99.546                -0.113320
#
#             us homeownership rate_2d  \
# date
# 2021-12-31                       0.3
# 2022-03-31                      -1.0
# 2022-06-30                       0.5
# 2022-09-30                       0.8
# 2022-12-31                      -0.4
#
#             Interest Rates: Long-Term Government Bond Yields: 10-Year: Main (Including Benchmark) for United States_2d  \
# date
# 2021-12-31                                           0.100000
# 2022-03-31                                          -0.486667
# 2022-06-30                                           0.060000
# 2022-09-30                                          -0.216667
# 2022-12-31                                           0.533333
#
#             us bankruptcy_1d  us bankruptcy_forecast  ...  GDP(Billions)_1d  \
# date                                                  ...
# 2021-12-31            4646.0                130889.0  ...          1635.816
# 2022-03-31           24135.0                155024.0  ...          1702.945
# 2022-06-30           29436.0                184460.0  ...          1797.321
# 2022-09-30            4532.0                188992.0  ...          1826.186
# 2022-12-31            -465.0                188527.0  ...          1724.787
#
#             GDP(Billions)_forecast  real GDP(Billions)_1d  \
# date
# 2021-12-31               23283.456               1379.997
# 2022-03-31               24986.401               1461.553
# 2022-06-30               26783.722               1520.655
# 2022-09-30               28609.908               1584.330
# 2022-12-31               30334.695               1484.784
#
#             real GDP(Billions)_forecast  us unemployment rate_1d  \
# date
# 2021-12-31                    21891.782                -4.348735
# 2022-03-31                    23353.335                -4.333945
# 2022-06-30                    24873.990                -4.635379
# 2022-09-30                    26458.320                -4.349626
# 2022-12-31                    27943.104                -4.462946
#
#             us unemployment rate_forecast  us homeownership rate_1d  \
# date
# 2021-12-31                       4.396811                      -0.2
# 2022-03-31                       0.062865                      -1.2
# 2022-06-30                      -4.572513                      -0.7
# 2022-09-30                      -8.922140                       0.1
# 2022-12-31                     -13.385086                      -0.3
#
#             us homeownership rate_forecast  \
# date
# 2021-12-31                            67.2
# 2022-03-31                            66.0
# 2022-06-30                            65.3
# 2022-09-30                            65.4
# 2022-12-31                            65.1
#
#             Interest Rates: Long-Term Government Bond Yields: 10-Year: Main (Including Benchmark) for United States_1d  \
# date
# 2021-12-31                                           0.063333
# 2022-03-31                                          -0.423333
# 2022-06-30                                          -0.363333
# 2022-09-30                                          -0.580000
# 2022-12-31                                          -0.046667
#
#             Interest Rates: Long-Term Government Bond Yields: 10-Year: Main (Including Benchmark) for United States_forecast
# date
# 2021-12-31                                           0.713333
# 2022-03-31                                           0.290000
# 2022-06-30                                          -0.073333
# 2022-09-30                                          -0.653333
# 2022-12-31                                          -0.700000
#
# [5 rows x 24 columns]

# %%
fig, axes = plt.subplots(nrows=int(len(df.columns)/2), ncols=2, dpi=150, figsize=(10,10))
for i, (col,ax) in enumerate(zip(df.columns, axes.flatten())):
    df_results[col+'_forecast'].plot(legend=True, ax=ax).autoscale(axis='x',tight=True)
    df_test[col][-12:].plot(legend=True, ax=ax);
    ax.set_title(col + ": Forecast vs Actuals")
    ax.xaxis.set_ticks_position('none')
    ax.yaxis.set_ticks_position('none')
    ax.spines["top"].set_alpha(0)
    ax.tick_params(labelsize=6)

plt.tight_layout();
